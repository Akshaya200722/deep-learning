# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshaya200722/deep-learning/blob/main/LeNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
def LeNet5(input_shape=(32, 32, 1), num_classes=10):
    model = models.Sequential()

    # C1: Convolution
    model.add(layers.Conv2D(6, kernel_size=5, activation='tanh', input_shape=input_shape))

    # S2: Average Pooling
    model.add(layers.AveragePooling2D(pool_size=2, strides=2))

    # C3: Convolution
    model.add(layers.Conv2D(16, kernel_size=5, activation='tanh'))

    # S4: Average Pooling
    model.add(layers.AveragePooling2D(pool_size=2, strides=2))

    # C5: Fully Connected via Conv
    model.add(layers.Flatten())
    model.add(layers.Dense(120, activation='tanh'))

    # F6
    model.add(layers.Dense(84, activation='tanh'))

    # Output
    model.add(layers.Dense(num_classes, activation='softmax'))

    return model

lenet = LeNet5()
lenet.summary()
